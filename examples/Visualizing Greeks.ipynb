# %% [markdown]
# ### Import libraries

# %%
import opstrat as op
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### TIME

# %%
K=100
St=95
r=4
vs=[10,25,40,60]
ts=[i for i in range(1,101)]
type='c'

df_list=[]
for v in vs:
    vals=[]
    vals_int=[]
    vals_time=[]
    deltas=[]
    gammas=[]
    thetas=[]
    rhos=[]
    vegas=[]
    for t in ts:
        params=op.black_scholes(t=t,K=K,St=St, r=r,v=v, type=type)

        vals.append(params['value']['option value'])
        vals_int.append(params['value']['intrinsic value'])
        vals_time.append(params['value']['time value'])
        deltas.append(params['greeks']['delta'])
        gammas.append(params['greeks']['gamma'])
        thetas.append(params['greeks']['theta'])
        rhos.append(params['greeks']['rho'])
        vegas.append(params['greeks']['vega'])
    df=pd.DataFrame({'vals':vals,'vals_int':vals_int,'vals_time': vals_time,
                     'delta':deltas,'gamma':gammas,'theta':thetas,
                     'rho':rhos,'vega':vegas})
    df_list.append(df)

# %%
for greek in ['delta','gamma','theta','rho','vega']:
    plt.figure(figsize=(10,6))
    for df,v in zip(df_list,vs):
        plt.plot(ts,df[greek], label=f'{greek} V:{v}%')
    plt.gca().invert_xaxis()
    plt.legend()
    plt.show()

# %%
greeks=[deltas,gammas,thetas,rhos,vegas]
labels=['delta','gamma','theta','rho','vega']

for greek,label in zip(greeks,labels):
    plt.figure(figsize=(10,6))
    plt.plot(ts,greek, label=label)
    plt.gca().invert_xaxis()
    plt.legend()
    plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ts,vals, label='option value')
plt.plot(ts,vals_time, label='time value')
plt.plot(ts, vals_int, label='intrinsic value')
plt.gca().invert_xaxis()
plt.legend()
plt.show()

# %%
params=op.black_scholes(t=5,K=K,St=St, r=r,v=v, type=type)

# %%
params['greeks']['theta']
# Out:
# np.float64(-0.21258628883604633)

# %%
vals_time
# Out:
# [np.float64(0.06628857027590307),
#  np.float64(0.26879311435324205),
#  np.float64(0.49719659151044837),
#  np.float64(0.723108519225871),
#  np.float64(0.9404624606474172),
#  np.float64(1.1482979366522805),
#  np.float64(1.3470210209633677),
#  np.float64(1.537387874916),
#  np.float64(1.7201935786038796),
#  np.float64(1.896175754108917),
#  np.float64(2.0659899355098226),
#  np.float64(2.2302096037534227),
#  np.float64(2.38933417107107),
#  np.float64(2.5437987735114582),
#  np.float64(2.693983656842775),
#  np.float64(2.840222452077427),
#  np.float64(2.9828092192761915),
#  np.float64(3.1220043509777256),
#  np.float64(3.2580394903640837),
#  np.float64(3.391121624355492),
#  np.float64(3.521436495730228),
